# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
train = pd.read_csv(r"E:\DATA ANALYSIS\TCS INTERNSHIP\MobileDataSets\MobileTrain.csv")
train
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
train.shape
# Out:
# (2000, 21)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
# ...

# %%
train.describe()
# Out:
#        battery_power       blue  clock_speed     dual_sim           fc  \
# count    2000.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     0.4950     1.522250     0.509500     4.309500
# std       439.418206     0.5001     0.816004     0.500035     4.341444
# min       501.000000     0.0000     0.500000     0.000000     0.000000
# 25%       851.750000     0.0000     0.700000     0.000000     1.000000
# 50%      1226.000000     0.0000     1.500000     1.000000     3.000000
# 75%      1615.250000     1.0000     2.200000     1.000000     7.000000
# max      1998.000000     1.0000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  ...  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000  ...
# mean      0.521500    32.046500     0.501750   140.249000     4.520500  ...
# std       0.499662    18.145715     0.288416    35.399655     2.287837  ...
# ...

# %%
train.columns
# Out:
# Index(['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
#        'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
#        'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi', 'price_range'],
#       dtype='object')

# %%
train.isna().sum()
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %%
train.nunique()
# Out:
# battery_power    1094
# blue                2
# clock_speed        26
# dual_sim            2
# fc                 20
# four_g              2
# int_memory         63
# m_dep              10
# mobile_wt         121
# n_cores             8
# pc                 21
# px_height        1137
# px_width         1109
# ram              1562
# sc_h               15
# sc_w               19
# talk_time          19
# three_g             2
# touch_screen        2
# wifi                2
# price_range         4
# dtype: int64

# %%
def understand_data(train) :
    
    return(pd.DataFrame({"Datatype":train.dtypes,
                         "No of NAs":train.isna().sum(),
                         "No of Levels":train.nunique(axis=0,dropna=True),
                         "Levels": train.apply(lambda x: str(x.unique()),axis=0)}))
understand_data(train)
# Out:
#               Datatype  No of NAs  No of Levels  \
# battery_power    int64          0          1094
# blue             int64          0             2
# clock_speed    float64          0            26
# dual_sim         int64          0             2
# fc               int64          0            20
# four_g           int64          0             2
# int_memory       int64          0            63
# m_dep          float64          0            10
# mobile_wt        int64          0           121
# n_cores          int64          0             8
# pc               int64          0            21
# px_height        int64          0          1137
# px_width         int64          0          1109
# ram              int64          0          1562
# sc_h             int64          0            15
# sc_w             int64          0            19
# talk_time        int64          0            19
# three_g          int64          0             2
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ### UNIVARIATE ANALYSIS

# %% [markdown]
# ### Countplot

# %%
sns.countplot(train['dual_sim'])
# Out:
# <AxesSubplot:xlabel='dual_sim', ylabel='count'>

# %%
sns.countplot(train['three_g'])
# Out:
# <AxesSubplot:xlabel='three_g', ylabel='count'>

# %%
sns.countplot(train['four_g'])
# Out:
# <AxesSubplot:xlabel='four_g', ylabel='count'>

# %%
sns.countplot(train['wifi'])
# Out:
# <AxesSubplot:xlabel='wifi', ylabel='count'>

# %%
sns.countplot(train['int_memory'])
# Out:
# <AxesSubplot:xlabel='int_memory', ylabel='count'>

# %%
sns.countplot(train['talk_time'])
# Out:
# <AxesSubplot:xlabel='talk_time', ylabel='count'>

# %%
sns.countplot(train['sc_h'])
# Out:
# <AxesSubplot:xlabel='sc_h', ylabel='count'>

# %%
sns.countplot(x ='price_range', hue='four_g', data=train)
# Out:
# <AxesSubplot:xlabel='price_range', ylabel='count'>

# %%
sns.countplot(x ='price_range', hue='three_g', data=train)
# Out:
# <AxesSubplot:xlabel='price_range', ylabel='count'>

# %%
sns.countplot(x ='talk_time', hue='price_range', data=train)
# Out:
# <AxesSubplot:xlabel='talk_time', ylabel='count'>

# %% [markdown]
# ### Histogram

# %%
#Plotting the histogram to understand more about variables

train.hist(figsize = (20,20))
plt.show()

# %% [markdown]
# ### Distplot

# %%
sns.distplot(train['battery_power'])
plt.title("Distplot of battery power")
plt.show()

sns.distplot(train['clock_speed'])
plt.title("Distplot of clock speed")
plt.show()

sns.distplot(train['fc'])
plt.title("Distplot of fc")
plt.show()

sns.distplot(train['int_memory'])
plt.title("Distplot of internal memory")
plt.show()

sns.distplot(train['m_dep'])
plt.title("Distplot of m dep")
plt.show()

sns.distplot(train['mobile_wt'])
plt.title("Distplot of mobile weight")
plt.show()

sns.distplot(train['n_cores'])
plt.title("Distplot of n cores")
plt.show()

sns.distplot(train['pc'])
plt.title("Distplot of pc")
plt.show()

sns.distplot(train['px_height'])
plt.title("Distplot of px height")
plt.show()

sns.distplot(train['px_width'])
plt.title("Distplot of px_width")
plt.show()

sns.distplot(train['ram'])
plt.title("Distplot of ram")
plt.show()

sns.distplot(train['sc_h'])
plt.title("Distplot of sc_h")
plt.show()

sns.distplot(train['sc_w'])
plt.title("Distplot of sc_w")
plt.show()

sns.distplot(train['talk_time'])
plt.title("Distplot of talk_time")
plt.show()

# %%
train.columns
# Out:
# Index(['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
#        'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
#        'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi', 'price_range'],
#       dtype='object')

# %%
train.nunique()
# Out:
# battery_power    1094
# blue                2
# clock_speed        26
# dual_sim            2
# fc                 20
# four_g              2
# int_memory         63
# m_dep              10
# mobile_wt         121
# n_cores             8
# pc                 21
# px_height        1137
# px_width         1109
# ram              1562
# sc_h               15
# sc_w               19
# talk_time          19
# three_g             2
# touch_screen        2
# wifi                2
# price_range         4
# dtype: int64

# %% [markdown]
# ### Bivariate Analysis

# %% [markdown]
# ### Histplot

# %%
#Analysis with respect to target variable "price_range"

for i in train.columns[:-1]:
    plt.figure(figsize=(10,10))
    sns.histplot(x=train[i], hue=train["price_range"], multiple="stack")
    print("Distribution of ",i ,"with respect to price range")
    plt.show()
# Out:
# Distribution of  battery_power with respect to price range
# Distribution of  blue with respect to price range
# Distribution of  clock_speed with respect to price range
# Distribution of  dual_sim with respect to price range
# Distribution of  fc with respect to price range
# Distribution of  four_g with respect to price range
# Distribution of  int_memory with respect to price range
# Distribution of  m_dep with respect to price range
# Distribution of  mobile_wt with respect to price range
# Distribution of  n_cores with respect to price range
# Distribution of  pc with respect to price range
# Distribution of  px_height with respect to price range
# Distribution of  px_width with respect to price range
# Distribution of  ram with respect to price range
# Distribution of  sc_h with respect to price range
# Distribution of  sc_w with respect to price range
# Distribution of  talk_time with respect to price range
# Distribution of  three_g with respect to price range
# ...

# %% [markdown]
# ### Boxplot

# %%
sns.boxplot(x='price_range', y='battery_power', data=train)
plt.show()

# %%
sns.boxplot(x='price_range', y='fc', data=train)
plt.show()

# %%
sns.boxplot(x='price_range', y='int_memory', data=train)
plt.show()

# %%
sns.boxplot(x='price_range', y='m_dep', data=train)
plt.show()

# %%
sns.boxplot(x='price_range', y='mobile_wt', data=train)
plt.show()

# %%
sns.boxplot(x='price_range', y='n_cores', data=train)
plt.show()

# %%
sns.boxplot(x='price_range', y='pc', data=train)
plt.show()

# %%
sns.boxplot(x='price_range', y='px_height', data=train)
plt.show()

# %%
sns.boxplot(x='price_range', y='px_width', data=train)
plt.show()

# %%
sns.boxplot(x='price_range', y='ram', data=train)
plt.show()

# %%
sns.boxplot(x='price_range', y='sc_h', data=train)
plt.show()

# %%
sns.boxplot(x='price_range', y='sc_w', data=train)
plt.show()

# %%
sns.boxplot(x='price_range', y='talk_time', data=train)
plt.show()

# %% [markdown]
# ### Violinplot

# %%
sns.violinplot(x='price_range', y='clock_speed', data=train)
plt.show()

# %%
sns.violinplot(x='price_range', y='int_memory', data=train)
plt.show()

# %% [markdown]
# ### Swarmplot

# %%
sns.swarmplot(x='price_range', y='int_memory', data=train)
plt.show()

# %%
sns.swarmplot(x='price_range', y='ram', data=train)
plt.show()

# %%
sns.swarmplot(x='price_range', y='fc', data=train)
plt.show()

# %% [markdown]
# ### Heatmap or correlation matrix

# %%
plt.figure(figsize=(20,15))       #correlation matrix
sns.heatmap(train.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Price_range is highly correlated with RAM. Nothing else is significant

# %% [markdown]
# ### Pairplot

# %%
slicedata=train[['price_range','battery_power','n_cores','ram','talk_time']]
sns.pairplot(slicedata)

# %% [markdown]
# ### Barplot

# %%
plt.figure()
sns.barplot(y="battery_power", x="price_range", data=train)
# Out:
# <AxesSubplot:xlabel='price_range', ylabel='battery_power'>

# %%
plt.figure()
sns.barplot(y="battery_power", x="n_cores", data=train)
# Out:
# <AxesSubplot:xlabel='n_cores', ylabel='battery_power'>

# %%
train.columns
# Out:
# Index(['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
#        'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
#        'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi', 'price_range'],
#       dtype='object')

# %%
train.nunique()
# Out:
# battery_power    1094
# blue                2
# clock_speed        26
# dual_sim            2
# fc                 20
# four_g              2
# int_memory         63
# m_dep              10
# mobile_wt         121
# n_cores             8
# pc                 21
# px_height        1137
# px_width         1109
# ram              1562
# sc_h               15
# sc_w               19
# talk_time          19
# three_g             2
# touch_screen        2
# wifi                2
# price_range         4
# dtype: int64

# %% [markdown]
# ## DATA PREPROCESSING

# %% [markdown]
# ### Checking Missing Values

# %%
train.isna().sum()
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %%
def plot_missing_vals(data,height):
    '''
    this function plots missing values as bars and appends text of missing values on the bar
    '''
    f,ax = plt.subplots(1,1,figsize=(25,20))
    na_df = pd.DataFrame(train.isna().sum()).reset_index()
    na_df.columns=['Columns','Missing Values']
    sns.barplot(data=na_df, x='Columns',y='Missing Values',edgecolor='white', linewidth=3,palette='dark')
    ax.tick_params('x',labelrotation=100)
    for i in na_df.index:
        ax.text(x=i,y=na_df['Missing Values'][i]+height, s=na_df['Missing Values'][i],ha="center", va="center", color="black",rotation=25,size=18)
    f.suptitle('Plot Of Missing Value',y=0.98,ha='center',va='center',size=15, weight=150)
    plt.show()

# %%
plot_missing_vals(train,0)

# %% [markdown]
# #### There is no missing values in the dataset

# %% [markdown]
# ### Outlier Detection

# %%
train_copy=train.drop(["price_range"],axis=1)
sns.boxplot(data=train_copy)
plt.xticks(rotation=90)
plt.show()

# %%
#A user-defined function for detcting the number of outliers
def Outlier_IQR(df):
    Q1=df.quantile(0.25)
    Q3=df.quantile(0.75)
    IQR=Q3-Q1
    df_final=(df<(Q1-1.5*IQR)) | (df>(Q3+1.5*IQR))
    return df_final.sum()

# %%
Outlier_IQR(train_copy)
# Out:
# battery_power      0
# blue               0
# clock_speed        0
# dual_sim           0
# fc                18
# four_g             0
# int_memory         0
# m_dep              0
# mobile_wt          0
# n_cores            0
# pc                 0
# px_height          2
# px_width           0
# ram                0
# sc_h               0
# sc_w               0
# talk_time          0
# three_g          477
# touch_screen       0
# wifi               0
# dtype: int64

# %%
pd.DataFrame(Outlier_IQR(train_copy))
# Out:
#                  0
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc              18
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        2
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g        477
# touch_screen     0
# wifi             0

# %%
def plot_Outliers(train_copy,height):
    '''
    this function plots outliers as bars and appends text of missing values on the bar
    '''
    f,ax = plt.subplots(1,1,figsize=(25,20))
    na_df = pd.DataFrame(Outlier_IQR(train_copy)).reset_index()
    na_df.columns=['Columns','Outliers']
    sns.barplot(data=na_df, x='Columns',y='Outliers',edgecolor='white', linewidth=1,palette='dark')
    ax.tick_params('x',labelrotation=100)
    for i in na_df.index:
        ax.text(x=i,y=na_df['Outliers'][i]+height, s=na_df['Outliers'][i],ha="center", va="center", color="black",rotation=25,size=18)
    f.suptitle('Plot Of Outliers',y=0.98,ha='center',va='center',size=15, weight=150)
    plt.show()

# %%
plot_Outliers(train_copy,0)

# %%
plt.figure(figsize=(25,10))
plt.subplot(1, 6, 1)
sns.boxplot(y="battery_power",data=train)
plt.title("Box plot of battery power")
            
plt.subplot(1, 6, 2)
sns.boxplot(y="clock_speed",data=train)
plt.title("Box plot of clock speed")

plt.subplot(1, 6, 3)
sns.boxplot(y="fc",data=train)
plt.title("Box plot of Front camera")

plt.subplot(1, 6, 4)
sns.boxplot(y="int_memory",data=train)
plt.title("Box plot of Internal memory")

plt.subplot(1, 6, 5)
sns.boxplot(y="m_dep",data=train)
plt.title("Box plot of depth")

plt.subplot(1, 6, 6)
sns.boxplot(y="mobile_wt",data=train)
plt.title("Box plot of weight")
plt.show()

# %%
plt.figure(figsize=(25,10))
plt.subplot(1, 6, 1)
sns.boxplot(y="pc",data=train)
plt.title("Box plot of primary camera")
            
plt.subplot(1, 6, 2)
sns.boxplot(y="px_height",data=train)
plt.title("Box plot of pixel height")

plt.subplot(1, 6, 3)
sns.boxplot(y="px_width",data=train)
plt.title("Box plot of pixel width")

plt.subplot(1, 6, 4)
sns.boxplot(y="ram",data=train)
plt.title("Box plot of RAM")

plt.subplot(1, 6, 5)
sns.boxplot(y="sc_h",data=train)
plt.title("Box plot of Screen Height")

plt.subplot(1, 6, 6)
sns.boxplot(y="sc_w",data=train)
plt.title("Box plot of Screen Width")
plt.show()

plt.figure(figsize=(2,5))
sns.boxplot(y="talk_time",data=train)
plt.title("Box plot of talk time")
plt.show()

# %% [markdown]
# ### Encoding

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
# ...

# %% [markdown]
# #### All the columns are numerical variables. So there is no need for encoding in this dataset.

# %% [markdown]
# ### Splitting dataset into Software and Hardware features

# %%
data1 = train.loc[:,['battery_power','blue','dual_sim','fc','four_g','int_memory','m_dep','mobile_wt',
                  'n_cores','pc','px_height','px_width','ram','sc_h','sc_w','price_range']]
data1
# Out:
#       battery_power  blue  dual_sim  fc  four_g  int_memory  m_dep  mobile_wt  \
# 0               842     0         0   1       0           7    0.6        188
# 1              1021     1         1   0       1          53    0.7        136
# 2               563     1         1   2       1          41    0.9        145
# 3               615     1         0   0       0          10    0.8        131
# 4              1821     1         0  13       1          44    0.6        141
# ...             ...   ...       ...  ..     ...         ...    ...        ...
# 1995            794     1         1   0       1           2    0.8        106
# 1996           1965     1         1   0       0          39    0.2        187
# 1997           1911     0         1   1       1          36    0.7        108
# 1998           1512     0         0   4       1          46    0.1        145
# 1999            510     1         1   5       1          45    0.9        168
#
# ...

# %%
data2 = train.loc[:,['talk_time','three_g','wifi','touch_screen','clock_speed']]
data2
# Out:
#       talk_time  three_g  wifi  touch_screen  clock_speed
# 0            19        0     1             0          2.2
# 1             7        1     0             1          0.5
# 2             9        1     0             1          0.5
# 3            11        1     0             0          2.5
# 4            15        1     0             1          1.2
# ...         ...      ...   ...           ...          ...
# 1995         19        1     0             1          0.5
# 1996         16        1     1             1          2.6
# 1997          5        1     0             1          0.9
# 1998         19        1     1             1          0.9
# 1999          2        1     1             1          2.0
#
# [2000 rows x 5 columns]

# %%
#Merging the dataset 
data3 = pd.concat([data1, data2], axis=1)
data3
# Out:
#       battery_power  blue  dual_sim  fc  four_g  int_memory  m_dep  mobile_wt  \
# 0               842     0         0   1       0           7    0.6        188
# 1              1021     1         1   0       1          53    0.7        136
# 2               563     1         1   2       1          41    0.9        145
# 3               615     1         0   0       0          10    0.8        131
# 4              1821     1         0  13       1          44    0.6        141
# ...             ...   ...       ...  ..     ...         ...    ...        ...
# 1995            794     1         1   0       1           2    0.8        106
# 1996           1965     1         1   0       0          39    0.2        187
# 1997           1911     0         1   1       1          36    0.7        108
# 1998           1512     0         0   4       1          46    0.1        145
# 1999            510     1         1   5       1          45    0.9        168
#
# ...

# %% [markdown]
# ### Ranking dataset

# %%
dt = train.copy()
dt["rank_by_price"] = dt["price_range"].rank()
dt1 = dt.copy()
dt1.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_width   ram  sc_h  sc_w  talk_time  three_g  \
# 0        188        2  ...       756  2549     9     7         19        0
# 1        136        3  ...      1988  2631    17     3          7        1
# 2        145        5  ...      1716  2603    11     2          9        1
# 3        131        6  ...      1786  2769    16     8         11        1
# 4        141        2  ...      1212  1411     8     2         15        1
#
#    touch_screen  wifi  price_range  rank_by_price
# ...

# %%
dt1.tail()
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_width   ram  sc_h  sc_w  talk_time  \
# 1995    0.8        106        6  ...      1890   668    13     4         19
# 1996    0.2        187        4  ...      1965  2032    11    10         16
# 1997    0.7        108        8  ...      1632  3057     9     1          5
# 1998    0.1        145        5  ...       670   869    18    10         19
# 1999    0.9        168        6  ...       754  3919    19     4          2
#
#       three_g  touch_screen  wifi  price_range  rank_by_price
# ...

# %%
dt1.rank_by_price.nunique
# Out:
# <bound method IndexOpsMixin.nunique of 0        750.5
# 1       1250.5
# 2       1250.5
# 3       1250.5
# 4        750.5
#          ...
# 1995     250.5
# 1996    1250.5
# 1997    1750.5
# 1998     250.5
# 1999    1750.5
# Name: rank_by_price, Length: 2000, dtype: float64>

# %%
#Sorting dataset into ranked price range
dt1.sort_values(by=["rank_by_price"])
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 1838            720     1          0.9         1  12       1          14
# 1762            808     1          0.5         1   3       0          46
# 419             914     1          0.9         0   2       0           4
# 846            1489     0          2.4         1   8       0          32
# 845            1907     0          2.0         0  13       0          55
# ...             ...   ...          ...       ...  ..     ...         ...
# 981            1046     1          2.8         1   0       1          58
# 982            1035     0          0.6         1   2       1          44
# 987            1688     0          2.5         0   0       1          21
# 956             862     0          2.3         0   9       1           6
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_width   ram  sc_h  sc_w  talk_time  \
# ...

# %%
#Ranking of all features using rank
dt2 = train.copy()
RankedDataset1 = dt2.rank()
RankedDataset1.sort_values(by="price_range")
# Out:
#       battery_power    blue  clock_speed  dual_sim      fc  four_g  \
# 1838          320.5  1505.5        638.5    1491.0  1853.0  1479.0
# 1762          435.5  1505.5        207.0    1491.0   993.5   479.0
# 419           589.0  1505.5        638.5     491.0   814.0   479.0
# 846          1323.5   505.5       1612.5    1491.0  1601.0   479.0
# 845          1875.0   505.5       1337.0     491.0  1895.5   479.0
# ...             ...     ...          ...       ...     ...     ...
# 981           753.0  1505.5       1868.0    1491.0   237.5  1479.0
# 982           737.5   505.5        450.5    1491.0   814.0  1479.0
# 987          1583.0   505.5       1678.5     491.0   237.5  1479.0
# 956           515.5   505.5       1544.5     491.0  1678.5  1479.0
# 1999           21.0  1505.5       1337.0    1491.0  1281.0  1479.0
#
#       int_memory   m_dep  mobile_wt  n_cores  ...  px_height  px_width  \
# 1838       432.0  1595.5     1414.5    872.5  ...      657.5     978.0
# ...

# %%
#Ranking all the features separately to correct output
# Because not all features are good when values are high and not all features are good when values are low
# It depends on each and every feature


b = dt2.copy()
b["rank_by_price"] = b["price_range"].rank(ascending=False,method="dense")
b["rank_by_battery"] = b["battery_power"].rank(ascending=False,method="dense")
b["rank_by_blueooth"] = b["blue"].rank(ascending=False,method="dense")
b["rank_by_clockspeed"] = b["clock_speed"].rank(ascending=False,method="dense")
b["rank_by_DualSIM"] = b["dual_sim"].rank(ascending=False,method="dense")
b["rank_by_fc"] = b["fc"].rank(ascending=False,method="dense")
b["rank_by_4G"] = b["four_g"].rank(ascending=False,method="dense")
b["rank_by_InternalMemory"] = b["int_memory"].rank(ascending=False,method="dense")
b["rank_by_mdep"] = b["m_dep"].rank(ascending=False,method="dense")
b["rank_by_weight"] = b["mobile_wt"].rank(ascending=True,method="dense")
b["rank_by_ncores"] = b["n_cores"].rank(ascending=False,method="dense")
b["rank_by_pc"] = b["pc"].rank(ascending=False,method="dense")
b["rank_by_height"] = b["px_height"].rank(ascending=False,method="dense")
b["rank_by_width"] = b["px_width"].rank(ascending=False,method="dense")
b["rank_by_ram"] = b["ram"].rank(ascending=False,method="dense")
b["rank_by_sch"] = b["sc_h"].rank(ascending=False,method="dense")
b["rank_by_scw"] = b["sc_w"].rank(ascending=False,method="dense")
b["rank_by_talktime"] = b["talk_time"].rank(ascending=False,method="dense")
b["rank_by_3G"] = b["three_g"].rank(ascending=False,method="dense")
b["rank_by_touchscreen"] = b["touch_screen"].rank(ascending=False,method="dense")
b["rank_by_wifi"] = b["wifi"].rank(ascending=False,method="dense")
b.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  rank_by_pc  rank_by_height  rank_by_width  \
# 0        188        2  ...        19.0          1119.0          923.0
# 1        136        3  ...        15.0           399.0           10.0
# 2        145        5  ...        15.0           175.0          208.0
# 3        131        6  ...        12.0           202.0          155.0
# 4        141        2  ...         7.0           209.0          592.0
#
#    rank_by_ram  rank_by_sch  rank_by_scw  rank_by_talktime  rank_by_3G  \
# ...

# %%
RankedDataset2 = b.iloc[:,21:]
RankedDataset2
# Out:
#       rank_by_price  rank_by_battery  rank_by_blueooth  rank_by_clockspeed  \
# 0               3.0            839.0               2.0                 9.0
# 1               2.0            712.0               1.0                26.0
# 2               2.0           1046.0               1.0                26.0
# 3               2.0           1006.0               1.0                 6.0
# 4               3.0            140.0               1.0                19.0
# ...             ...              ...               ...                 ...
# 1995            4.0            878.0               1.0                26.0
# 1996            2.0             30.0               1.0                 5.0
# 1997            1.0             67.0               2.0                22.0
# 1998            4.0            362.0               2.0                22.0
# 1999            1.0           1086.0               1.0                11.0
#
# ...

# %% [markdown]
# ### Standardization

# %%
X=train.drop('price_range',axis=1)
y=train['price_range']

# %%
X.describe()
# Out:
#        battery_power       blue  clock_speed     dual_sim           fc  \
# count    2000.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     0.4950     1.522250     0.509500     4.309500
# std       439.418206     0.5001     0.816004     0.500035     4.341444
# min       501.000000     0.0000     0.500000     0.000000     0.000000
# 25%       851.750000     0.0000     0.700000     0.000000     1.000000
# 50%      1226.000000     0.0000     1.500000     1.000000     3.000000
# 75%      1615.250000     1.0000     2.200000     1.000000     7.000000
# max      1998.000000     1.0000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000
# mean      0.521500    32.046500     0.501750   140.249000     4.520500
# std       0.499662    18.145715     0.288416    35.399655     2.287837
# ...

# %%
cols=X.columns
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
df_scaled = sc.fit_transform(X)
df_scaled = pd.DataFrame(df_scaled, columns=cols)
df_scaled
# Out:
#       battery_power      blue  clock_speed  dual_sim        fc    four_g  \
# 0         -0.902597 -0.990050     0.830779 -1.019184 -0.762495 -1.043966
# 1         -0.495139  1.010051    -1.253064  0.981177 -0.992890  0.957886
# 2         -1.537686  1.010051    -1.253064  0.981177 -0.532099  0.957886
# 3         -1.419319  1.010051     1.198517 -1.019184 -0.992890 -1.043966
# 4          1.325906  1.010051    -0.395011 -1.019184  2.002254  0.957886
# ...             ...       ...          ...       ...       ...       ...
# 1995      -1.011860  1.010051    -1.253064  0.981177 -0.992890  0.957886
# 1996       1.653694  1.010051     1.321096  0.981177 -0.992890 -1.043966
# 1997       1.530773 -0.990050    -0.762748  0.981177 -0.762495  0.957886
# 1998       0.622527 -0.990050    -0.762748 -1.019184 -0.071307  0.957886
# 1999      -1.658331  1.010051     0.585621  0.981177  0.159088  0.957886
#
#       int_memory     m_dep  mobile_wt   n_cores        pc  px_height  \
# ...

# %%
df_scaled.describe()
# Out:
#        battery_power          blue   clock_speed      dual_sim            fc  \
# count   2.000000e+03  2.000000e+03  2.000000e+03  2.000000e+03  2.000000e+03
# mean    2.128298e-16 -1.927347e-16 -2.172151e-16  3.990142e-16  9.230117e-17
# std     1.000250e+00  1.000250e+00  1.000250e+00  1.000250e+00  1.000250e+00
# min    -1.678817e+00 -9.900495e-01 -1.253064e+00 -1.019184e+00 -9.928904e-01
# 25%    -8.804033e-01 -9.900495e-01 -1.007906e+00 -1.019184e+00 -7.624947e-01
# 50%    -2.849593e-02 -9.900495e-01 -2.727384e-02  9.811771e-01 -3.017032e-01
# 75%     8.575560e-01  1.010051e+00  8.307794e-01  9.811771e-01  6.198797e-01
# max     1.728812e+00  1.010051e+00  1.811412e+00  9.811771e-01  3.384628e+00
#
#              four_g    int_memory         m_dep     mobile_wt       n_cores  \
# count  2.000000e+03  2.000000e+03  2.000000e+03  2.000000e+03  2.000000e+03
# mean  -2.048361e-16 -8.754109e-17 -1.045830e-16  1.804112e-16 -4.690692e-17
# ...

# %%
df_scaled.columns
# Out:
# Index(['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
#        'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
#        'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi'],
#       dtype='object')

# %% [markdown]
# ### Model building

# %%
#Checking the imbalance of the dataset
y.value_counts(normalize=True).to_frame()
# Out:
#    price_range
# 1         0.25
# 2         0.25
# 3         0.25
# 0         0.25

# %% [markdown]
# #### This is a balanced dataset

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train, y_test = train_test_split(X,y,test_size=0.25, random_state=0)

# %%
# LogisticRegression
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr_model=lr.fit(X_train, y_train)

y_pred = lr.predict(X_test)

# Summary of the predictions made by the classifier
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score


print(classification_report(y_test, y_pred))
cm=(confusion_matrix(y_test, y_pred))
print(cm)

# Accuracy score
print('Accuracy score is',accuracy_score(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.84      0.85       124
#            1       0.54      0.57      0.56       110
#            2       0.47      0.46      0.47       125
#            3       0.72      0.71      0.71       141
#
#     accuracy                           0.65       500
#    macro avg       0.65      0.65      0.65       500
# weighted avg       0.65      0.65      0.65       500
#
# [[104  18   2   0]
#  [ 17  63  25   5]
#  [  0  33  58  34]
#  [  0   2  39 100]]
# Accuracy score is 0.65

# %%
sns.heatmap(cm,annot=True)
plt.xlabel('Actual values')
plt.ylabel("Predicted values")
plt.figure(figsize=(20,7))

# %%
# Support Vector Machine  

from sklearn.svm import SVC

svm = SVC(kernel='linear')
svm_model=svm.fit(X_train, y_train)

y_pred = svm.predict(X_test)

# Summary of the predictions made by the classifier
print(classification_report(y_test, y_pred))
cm=(confusion_matrix(y_test, y_pred))
print(cm)

# Accuracy score
print('Accuracy score is',accuracy_score(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       124
#            1       0.97      0.97      0.97       110
#            2       0.95      0.98      0.96       125
#            3       0.99      0.97      0.98       141
#
#     accuracy                           0.98       500
#    macro avg       0.98      0.98      0.98       500
# weighted avg       0.98      0.98      0.98       500
#
# [[123   1   0   0]
#  [  1 107   2   0]
#  [  0   2 122   1]
#  [  0   0   4 137]]
# Accuracy score is 0.978

# %%
sns.heatmap(cm,annot=True)
plt.xlabel('Actual values')
plt.ylabel("Predicted values")
plt.figure(figsize=(20,7))
plt.show()

# %%
# Decision Tree

from sklearn.tree import DecisionTreeClassifier

dt= DecisionTreeClassifier()

dt_model = dt.fit(X_train, y_train)

y_pred = dt.predict(X_test)

# Summary of the predictions made by the classifier
print(classification_report(y_test, y_pred))
cm=(confusion_matrix(y_test, y_pred))
print(cm)
# Accuracy score
print('Accuracy score is',accuracy_score(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.90      0.91       124
#            1       0.74      0.75      0.75       110
#            2       0.71      0.68      0.69       125
#            3       0.83      0.87      0.85       141
#
#     accuracy                           0.80       500
#    macro avg       0.80      0.80      0.80       500
# weighted avg       0.80      0.80      0.80       500
#
# [[111  13   0   0]
#  [  9  83  18   0]
#  [  0  15  85  25]
#  [  0   1  17 123]]
# Accuracy score is 0.804

# %%
sns.heatmap(cm,annot=True)
plt.xlabel('Actual values')
plt.ylabel("Predicted values")
plt.figure(figsize=(20,7))
plt.show()

# %%
# Random Forest 
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(n_estimators=500,max_depth=10,random_state =42,
                            criterion='entropy',max_features='log2')
rf_model = rf.fit(X_train,y_train) #training the data set

y_predict = rf.predict(X_test) #predicting based on test data

# Summary of the predictions made by the classifier
print(classification_report(y_test, y_pred))
cm=(confusion_matrix(y_test, y_pred))
print(cm)
# Accuracy score
print('Accuracy score is',accuracy_score(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.90      0.91       124
#            1       0.74      0.75      0.75       110
#            2       0.71      0.68      0.69       125
#            3       0.83      0.87      0.85       141
#
#     accuracy                           0.80       500
#    macro avg       0.80      0.80      0.80       500
# weighted avg       0.80      0.80      0.80       500
#
# [[111  13   0   0]
#  [  9  83  18   0]
#  [  0  15  85  25]
#  [  0   1  17 123]]
# Accuracy score is 0.804

# %%
sns.heatmap(cm,annot=True)
plt.xlabel('Actual values')
plt.ylabel("Predicted values")
plt.figure(figsize=(20,7))
plt.show()

# %%
#Gradient Boosting
from sklearn.ensemble import GradientBoostingClassifier
gb = GradientBoostingClassifier()
gb_model =gb.fit(X_train,y_train)
y_pred = gb.predict(X_test)

# Summary of the predictions made by the classifier
print(classification_report(y_test, y_pred))
cm=(confusion_matrix(y_test, y_pred))
print(cm)

# Accuracy score
print('Accuracy score is',accuracy_score(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98       124
#            1       0.90      0.91      0.90       110
#            2       0.87      0.87      0.87       125
#            3       0.94      0.93      0.94       141
#
#     accuracy                           0.92       500
#    macro avg       0.92      0.92      0.92       500
# weighted avg       0.92      0.92      0.92       500
#
# [[121   3   0   0]
#  [  3 100   7   0]
#  [  0   8 109   8]
#  [  0   0  10 131]]
# Accuracy score is 0.922

# %%
sns.heatmap(cm,annot=True)
plt.xlabel('Actual values')
plt.ylabel("Predicted values")
plt.figure(figsize=(20,7))
plt.show()

# %%
! python -m pip install xgboost
from xgboost import XGBClassifier 
xgb= XGBClassifier()
xgb_model = xgb.fit(X_train,y_train)

y_pred = xgb.predict(X_test)

# Summary of the predictions made by the classifier
print(classification_report(y_test, y_pred))
cm=(confusion_matrix(y_test, y_pred))
print(cm)
# Accuracy score
print('Accuracy score is',accuracy_score(y_pred,y_test))
# Out:
# ...
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.97       124
#            1       0.89      0.89      0.89       110
#            2       0.89      0.84      0.86       125
#            3       0.93      0.95      0.94       141
#
#     accuracy                           0.92       500
#    macro avg       0.92      0.92      0.92       500
# weighted avg       0.92      0.92      0.92       500
#
# [[122   2   0   0]
#  [  6  98   6   0]
#  [  0  10 105  10]
#  [  0   0   7 134]]
# Accuracy score is 0.918

# %%
sns.heatmap(cm,annot=True)
plt.xlabel('Actual values')
plt.ylabel("Predicted values")
plt.figure(figsize=(20,7))
plt.show()

# %%
# Naive Bayes
from sklearn.naive_bayes import GaussianNB

gnb = GaussianNB()
gnb_model= gnb.fit(X_train, y_train)
y_pred = gnb.predict(X_test)

# Summary of the predictions made by the classifier
print(classification_report(y_test, y_pred))
cm=(confusion_matrix(y_test, y_pred))
print(cm)
# Accuracy score
print('Accuracy score is',accuracy_score(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.94      0.95       124
#            1       0.74      0.75      0.75       110
#            2       0.74      0.73      0.73       125
#            3       0.92      0.92      0.92       141
#
#     accuracy                           0.84       500
#    macro avg       0.84      0.84      0.84       500
# weighted avg       0.84      0.84      0.84       500
#
# [[117   7   0   0]
#  [  6  83  21   0]
#  [  0  22  91  12]
#  [  0   0  11 130]]
# Accuracy score is 0.842

# %%
sns.heatmap(cm,annot=True)
plt.xlabel('Actual values')
plt.ylabel("Predicted values")
plt.figure(figsize=(20,7))
plt.show()

# %%
from sklearn.metrics import accuracy_score, log_loss
classifiers = [
   LogisticRegression(),
    SVC(kernel='linear'),
    DecisionTreeClassifier(),
    RandomForestClassifier(),
    GradientBoostingClassifier(),
    XGBClassifier(),
    GaussianNB()
                  ]
 
# Logging for Visual Comparison
log_cols=["Classifier", "Accuracy", "Log Loss"]
log = pd.DataFrame(columns=log_cols)
 
for clf in classifiers:
    clf.fit(X_train, y_train)
    name = clf.__class__.__name__
    
    print("="*30)
    print(name)
    
    print('****Results****')
    train_predictions = clf.predict(X_test)
    acc = accuracy_score(y_test, train_predictions)
    print("Accuracy: {:.4%}".format(acc))
    
    log_entry = pd.DataFrame([[name, acc*100, 11]], columns=log_cols)
    log = log.append(log_entry)
    
    print("="*30)
# Out:
# ...
# LogisticRegression
# ****Results****
# Accuracy: 65.0000%
# ...
# SVC
# ****Results****
# Accuracy: 97.8000%
# ...
# DecisionTreeClassifier
# ****Results****
# Accuracy: 81.4000%
# ...
# RandomForestClassifier
# ****Results****
# Accuracy: 87.6000%
# ...
# GradientBoostingClassifier
# ****Results****
# Accuracy: 92.0000%
# ...
# XGBClassifier
# ****Results****
# Accuracy: 91.8000%
# ...
# GaussianNB
# ****Results****
# Accuracy: 84.2000%
# ...

# %%
sns.barplot(x='Accuracy', y='Classifier', data=log, color="b")

plt.xlabel('Accuracy %')
plt.title('Classifier Accuracy')
plt.show()

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

kfold = KFold(n_splits = 10)
xyz = []
accuracy = []

classifiers=["SVM","Logistic Regression","Decision Tree","Random Forest","GaussianNB"]
models=[SVC(kernel='rbf'),LogisticRegression(),DecisionTreeClassifier(),RandomForestClassifier(n_estimators=300,random_state=0),GaussianNB()]

for i in models:
    model = i
    cv_result=cross_val_score(model,X_train,y_train,cv=kfold,scoring="accuracy")
    cv_result = cv_result
    xyz.append(cv_result.mean())
    accuracy.append(cv_result)
    
cv_models_datafeame= pd.DataFrame(xyz, index = classifiers)
cv_models_datafeame.columns = ['CV Mean']
cv_models_datafeame
cv_models_datafeame.sort_values(['CV Mean'], ascending =[0])

box = pd.DataFrame(accuracy, index = [classifiers])
boxT = box.T
plt.figure(figsize = (10,7))
ax = sns.boxplot(data = boxT, orient = "h", palette = "Set2", width = 0.6)
ax.set_yticklabels(classifiers)
ax.set_title('Cross Validation accuracy with different classifiers')
ax.set_xlabel('Accuracy')

plt.show()

# %% [markdown]
# ### The Support Vector Machine classification model has the highest accuracy score.

# %% [markdown]
# ### Test data to predict the results

# %%
test = pd.read_csv(r"E:\DATA ANALYSIS\TCS INTERNSHIP\MobileDataSets\MobileTest.csv",index_col = 'id')
test.head()
# Out:
#     battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# id
# 1            1043     1          1.8         1  14       0           5    0.1
# 2             841     1          0.5         1   4       1          61    0.8
# 3            1807     1          2.8         0   1       0          27    0.9
# 4            1546     0          0.5         1  18       1          25    0.5
# 5            1434     0          1.4         0  11       1          49    0.5
#
#     mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# id
# 1         193        3  16        226      1412  3476    12     7          2
# 2         191        5  12        746       857  3895     6     0          7
# 3         186        3   4       1270      1366  2396    17    10         10
# 4          96        8  20        295      1752  3893    10     0          7
# 5         108        6  18        749       810  1773    15     8          7
#
# ...

# %%
test.shape
# Out:
# (1000, 20)

# %%
test_scaled = sc.fit_transform(test)
test_scaled
# Out:
# array([[-0.47545131,  0.968496  ,  0.31260069, ..., -1.76021608,
#          1.        , -1.01409939],
#        [-0.94278218,  0.968496  , -1.25583195, ...,  0.56811207,
#         -1.        , -1.01409939],
#        [ 1.29207729,  0.968496  ,  1.51908734, ..., -1.76021608,
#          1.        ,  0.98609664],
#        ...,
#        [-0.1469316 , -1.03252879, -0.16999397, ...,  0.56811207,
#         -1.        , -1.01409939],
#        [ 0.65817305,  0.968496  , -1.25583195, ..., -1.76021608,
#          1.        , -1.01409939],
#        [ 0.04971753,  0.968496  , -1.25583195, ...,  0.56811207,
#         -1.        ,  0.98609664]])

# %%
test_pred=svm.predict(test_scaled)

# %%
result = pd.DataFrame(test_pred)

# %%
result.to_csv('result.csv')
